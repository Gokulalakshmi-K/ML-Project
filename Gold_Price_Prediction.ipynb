# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulalakshmi-K/ML-Project/blob/main/Gold_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Importing Required Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy import stats

# %% [markdown]
# ## **Peeking at the data**

# %%
gold_data = pd.read_csv("gld_price_data.csv")
gold_data.head()

# %%
X = gold_data.drop(['Date','GLD'],axis=1)
Y = gold_data['GLD']
print(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %% [markdown]
# # **Training the Algorithm**

# %%
clf = LinearRegression()
clf.fit(X,Y)
print(clf.score(X,Y))
# Out:
# 0.8814109874179616

# %% [markdown]
# # **Checking Accuracy of Prediction**

# %%
predictions = clf.predict(X_test)
mse = mean_squared_error(Y_test, predictions)
print("MSE :",mse)
# Out:
# MSE : 70.3516423811018

# %% [markdown]
# ## **Visualizing the Accuracy**

# %%
import matplotlib.pyplot as plt

Y_test = list(Y_test)
plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(predictions, color='red', label='Predicted Value')

plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(Y_test,predictions,c='crimson')
plt.scatter(predictions,Y_test,c='yellow')

plt.yscale('log')
plt.xscale('log')

p1 = max(max(predictions), max(Y_test))
p2 = min(min(predictions), min(Y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Original_value', fontsize=15)
plt.ylabel('Predicted_value', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(Y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')


plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(predictions, color='green', label = 'Actual Value')
plt.xlabel('Original_value', fontsize=15)
plt.ylabel('Predicted_value', fontsize=15)
plt.axis('equal')
plt.show()
